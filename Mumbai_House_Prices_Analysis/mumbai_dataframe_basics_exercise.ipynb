# %% [markdown]
# **Rahul Sharma** arrived in Mumbai(a city in India) with the aim of finding a suitable house that fits his budget and location preferences. He has some queries related to house selection and is seeking solutions.
#
# Help Rahul Sharma to answer his questions and you are provided with a sample dataset of house information that contain area_type, availability, location, size, society, total_sqft, bath, balcony, and price.

# %%
import pandas as pd

# %% [markdown]
# ### <font color="purple">**Question1**</font>
# - Read the csv file 'bengaluru_house_prices.csv' and store it in variable 'df'.
# - print the number of rows and columns in it
# - print the Top 5 rows

# %%
#read the csv file
df=pd.read_csv("mumbai_house_prices.csv")

#show the number of rows and columns in dataframe 'df'

df

#show Top5 rows
df.head(5)
# Out:
#               area_type   availability     location       size  society  \
# 0  Super built-up  Area  Ready To Move      Andheri      3 BHK      NaN
# 1            Plot  Area         18-Aug       Bandra  4 Bedroom  ValleCi
# 2  Super built-up  Area  Ready To Move        Powai      2 BHK  Sothin
# 3            Plot  Area  Ready To Move        Thane  2 Bedroom      NaN
# 4  Super built-up  Area  Ready To Move  Navi Mumbai      2 BHK  Prncyrn
#
#    total_sqft  bath  balcony  price
# 0        1920   4.0      2.0  121.0
# 1        1500   4.0      3.0  192.0
# 2         925   2.0      1.0   55.0
# 3         500   1.0      0.0   55.0
# 4        1174   2.0      1.0   74.0

# %%
df.shape
# Out:
# (50, 9)

# %% [markdown]
# ### <font color="purple">**Question2**</font>
# - show the unique categories present in **'area_type'** and **'size'** columns

# %%
#unique values in 'area_type' column
df.area_type.unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
#unique values in 'size' column
df['size'].unique()
# Out:
# array(['3 BHK', '4 Bedroom', '2 BHK', '2 Bedroom', '1 BHK', '5 BHK',
#        '3 Bedroom', '5 Bedroom', '1 Bedroom'], dtype=object)

# %% [markdown]
# ### <font color="purple">**Question3**</font>
# - Filter data which have **'2 BHK'** house size and area_type of **'Super built-up  Area'**
# - Also get the count of such rows

# %%
#filter the data
df[df['size']=='2 BHK']
# Out:
#                area_type   availability     location   size  society  \
# 2   Super built-up  Area  Ready To Move        Powai  2 BHK  Sothin
# 4   Super built-up  Area  Ready To Move  Navi Mumbai  2 BHK  Prncyrn
# 5   Super built-up  Area  Ready To Move        Dadar  2 BHK  HRaniIb
# 8   Super built-up  Area  Ready To Move     Goregaon  2 BHK  ShdhiSa
# 11  Super built-up  Area         17-Oct        Worli  2 BHK  ViistLa
# 14  Super built-up  Area  Ready To Move        Vashi  2 BHK  PrityTr
# 21  Super built-up  Area         18-Apr       Bandra  2 BHK      NaN
# 24  Super built-up  Area  Ready To Move  Navi Mumbai  2 BHK  GeereEc
# 25  Super built-up  Area  Ready To Move        Dadar  2 BHK      NaN
# 30        Built-up  Area  Ready To Move      Chembur  2 BHK      NaN
# 32  Super built-up  Area  Ready To Move  Lower Parel  2 BHK  Pyikad
# 33  Super built-up  Area  Ready To Move       Mulund  2 BHK  CMard B
# 35  Super built-up  Area         17-Mar         Khar  2 BHK  Uptusol
# 36        Built-up  Area  Ready To Move    Santacruz  2 BHK      NaN
# 37  Super built-up  Area  Ready To Move        Kurla  2 BHK  Sriferi
# 38  Super built-up  Area  Ready To Move       Colaba  2 BHK  GMown E
# 39  Super built-up  Area  Ready To Move       Panvel  2 BHK      NaN
# 41  Super built-up  Area  Ready To Move       Bandra  2 BHK  Prrtht
# 42  Super built-up  Area  Ready To Move        Powai  2 BHK  RInceeg
# 45  Super built-up  Area  Ready To Move        Dadar  2 BHK      NaN
# 46        Built-up  Area  Ready To Move     Borivali  2 BHK      NaN
# 48  Super built-up  Area  Ready To Move     Goregaon  2 BHK  Maidsr
# 49  Super built-up  Area  Ready To Move         Juhu  2 BHK      NaN
#
#     total_sqft  bath  balcony   price
# 2          925   2.0      1.0   55.00
# 4         1174   2.0      1.0   74.00
# 5         1202   2.0      1.0   79.00
# 8         1200   2.0      2.0   79.55
# 11        1235   2.0      1.0   52.04
# 14        1153   2.0      2.0   56.55
# 21        1120   2.0      2.0   40.00
# 24        1363   2.0      2.0   68.00
# 25        1175   2.0      2.0   42.00
# 30         850   2.0      0.0   35.00
# 32        1274   2.0      2.0   48.42
# 33        1005   2.0      1.0   55.00
# 35        1385   2.0      3.0   80.00
# 36        1125   2.0      1.0   46.00
# 37        1176   2.0      2.0   50.00
# 38         770   1.0      1.0   40.00
# 39        1195   2.0      1.0   35.84
# 41         883   2.0      1.0   37.00
# 42        1243   2.0      2.0   46.00
# 45        1200   2.0      3.0  120.00
# 46         936   2.0      0.0   40.20
# 48        1075   2.0      2.0   45.00
# 49        1225   2.0      1.0   47.00

# %%
#show the number of rows for the filtered data
df[df['size']=='2 BHK'].area_type.count()
# Out:
# np.int64(23)

# %% [markdown]
# ### <font color="purple">**Question4**</font>
# - Add a new column **'price_category'** which contain a category based on the price of house.
# - If price of house is less than 80, **"Affordable"**, otherwise **"High Cost"**

# %%
#Add the column 'price_category'
def price_category(row):
    if(row['price']<80):
        return "Affordable"
    return "High Cost"
df['price_category']=df.apply(price_category,axis=1);
df
# Out:
#                area_type   availability     location       size  society  \
# 0   Super built-up  Area  Ready To Move      Andheri      3 BHK      NaN
# 1             Plot  Area         18-Aug       Bandra  4 Bedroom  ValleCi
# 2   Super built-up  Area  Ready To Move        Powai      2 BHK  Sothin
# 3             Plot  Area  Ready To Move        Thane  2 Bedroom      NaN
# 4   Super built-up  Area  Ready To Move  Navi Mumbai      2 BHK  Prncyrn
# 5   Super built-up  Area  Ready To Move        Dadar      2 BHK  HRaniIb
# 6   Super built-up  Area         18-May     Borivali      3 BHK      NaN
# 7   Super built-up  Area         21-Dec        Malad      1 BHK  PrarePa
# 8   Super built-up  Area  Ready To Move     Goregaon      2 BHK  ShdhiSa
# 9             Plot  Area  Ready To Move         Juhu  4 Bedroom  Adowslm
# 10  Super built-up  Area  Ready To Move      Chembur      3 BHK  JRrnauv
# 11  Super built-up  Area         17-Oct        Worli      2 BHK  ViistLa
# 12  Super built-up  Area         18-May  Lower Parel      3 BHK  ViistLa
# 13  Super built-up  Area  Ready To Move       Mulund      3 BHK  SNity S
# 14  Super built-up  Area  Ready To Move        Vashi      2 BHK  PrityTr
# 15  Super built-up  Area         18-Aug         Khar      1 BHK  SunceEs
# 16  Super built-up  Area         18-Dec    Santacruz      3 BHK  Mahosya
# 17  Super built-up  Area  Ready To Move        Kurla      3 BHK  J axyGa
# 18        Built-up  Area  Ready To Move       Colaba      5 BHK      NaN
# 19  Super built-up  Area  Ready To Move       Panvel      3 BHK  Sovar S
# 20  Super built-up  Area  Ready To Move      Andheri      3 BHK  VDenaWa
# 21  Super built-up  Area         18-Apr       Bandra      2 BHK      NaN
# 22        Built-up  Area  Ready To Move        Powai      3 BHK  Keort F
# 23  Super built-up  Area         18-May        Thane      3 BHK      NaN
# 24  Super built-up  Area  Ready To Move  Navi Mumbai      2 BHK  GeereEc
# 25  Super built-up  Area  Ready To Move        Dadar      2 BHK      NaN
# 26  Super built-up  Area  Ready To Move     Borivali      3 BHK  BrdgeNo
# 27          Carpet  Area  Ready To Move        Malad  4 Bedroom      NaN
# 28  Super built-up  Area  Ready To Move     Goregaon      3 BHK      NaN
# 29            Plot  Area  Ready To Move         Juhu  3 Bedroom      NaN
# 30        Built-up  Area  Ready To Move      Chembur      2 BHK      NaN
# 31  Super built-up  Area  Ready To Move        Worli      3 BHK  Sahtsva
# 32  Super built-up  Area  Ready To Move  Lower Parel      2 BHK  Pyikad
# 33  Super built-up  Area  Ready To Move       Mulund      2 BHK  CMard B
# 34  Super built-up  Area  Ready To Move        Vashi      3 BHK      NaN
# 35  Super built-up  Area         17-Mar         Khar      2 BHK  Uptusol
# 36        Built-up  Area  Ready To Move    Santacruz      2 BHK      NaN
# 37  Super built-up  Area  Ready To Move        Kurla      2 BHK  Sriferi
# 38  Super built-up  Area  Ready To Move       Colaba      2 BHK  GMown E
# 39  Super built-up  Area  Ready To Move       Panvel      2 BHK      NaN
# 40            Plot  Area  Ready To Move      Andheri  3 Bedroom  CoinoCu
# 41  Super built-up  Area  Ready To Move       Bandra      2 BHK  Prrtht
# 42  Super built-up  Area  Ready To Move        Powai      2 BHK  RInceeg
# 43        Built-up  Area  Ready To Move        Thane  5 Bedroom      NaN
# 44            Plot  Area  Ready To Move  Navi Mumbai  1 Bedroom      NaN
# 45  Super built-up  Area  Ready To Move        Dadar      2 BHK      NaN
# 46        Built-up  Area  Ready To Move     Borivali      2 BHK      NaN
# 47  Super built-up  Area  Ready To Move        Malad      3 BHK      NaN
# 48  Super built-up  Area  Ready To Move     Goregaon      2 BHK  Maidsr
# 49  Super built-up  Area  Ready To Move         Juhu      2 BHK      NaN
#
#     total_sqft  bath  balcony   price price_category
# 0         1920   4.0      2.0  121.00      High Cost
# 1         1500   4.0      3.0  192.00      High Cost
# 2          925   2.0      1.0   55.00     Affordable
# 3          500   1.0      0.0   55.00     Affordable
# 4         1174   2.0      1.0   74.00     Affordable
# 5         1202   2.0      1.0   79.00     Affordable
# 6         1250   2.0      2.0   44.00     Affordable
# 7          525   1.0      1.0   26.00     Affordable
# 8         1200   2.0      2.0   79.55     Affordable
# 9         3100   4.0      2.0  350.00      High Cost
# 10        1550   3.0      3.0   65.10     Affordable
# 11        1235   2.0      1.0   52.04     Affordable
# 12        1475   2.0      2.0   63.00     Affordable
# 13        1520   2.0      3.0   81.00      High Cost
# 14        1153   2.0      2.0   56.55     Affordable
# 15         645   1.0      1.0   16.45     Affordable
# 16        1920   3.0      2.0  134.00      High Cost
# 17        1300   2.0      2.0   75.00     Affordable
# 18        3600   5.0      3.0  145.00      High Cost
# 19        1530   2.0      2.0   74.40     Affordable
# 20        2800   3.0      2.0  250.00      High Cost
# 21        1120   2.0      2.0   40.00     Affordable
# 22        1500   3.0      2.0   75.00     Affordable
# 23        1115   3.0      1.0   39.14     Affordable
# 24        1363   2.0      2.0   68.00     Affordable
# 25        1175   2.0      2.0   42.00     Affordable
# 26        1710   3.0      2.0  110.00      High Cost
# 27        2100   3.0      0.0  210.00      High Cost
# 28        1340   2.0      2.0   53.60     Affordable
# 29         980   3.0      1.0   80.00      High Cost
# 30         850   2.0      0.0   35.00     Affordable
# 31        1354   3.0      1.0   90.00      High Cost
# 32        1274   2.0      2.0   48.42     Affordable
# 33        1005   2.0      1.0   55.00     Affordable
# 34        1355   2.0      3.0   58.25     Affordable
# 35        1385   2.0      3.0   80.00      High Cost
# 36        1125   2.0      1.0   46.00     Affordable
# 37        1176   2.0      2.0   50.00     Affordable
# 38         770   1.0      1.0   40.00     Affordable
# 39        1195   2.0      1.0   35.84     Affordable
# 40        2500   3.0      2.0  190.00      High Cost
# 41         883   2.0      1.0   37.00     Affordable
# 42        1243   2.0      2.0   46.00     Affordable
# 43        2800   5.0      3.0  130.00      High Cost
# 44         410   1.0      1.0   48.00     Affordable
# 45        1200   2.0      3.0  120.00      High Cost
# 46         936   2.0      0.0   40.20     Affordable
# 47        1464   3.0      2.0   56.00     Affordable
# 48        1075   2.0      2.0   45.00     Affordable
# 49        1225   2.0      1.0   47.00     Affordable

# %%
#show the updated dataframe: top5 rows
df.head(5)
# Out:
#               area_type   availability     location       size  society  \
# 0  Super built-up  Area  Ready To Move      Andheri      3 BHK      NaN
# 1            Plot  Area         18-Aug       Bandra  4 Bedroom  ValleCi
# 2  Super built-up  Area  Ready To Move        Powai      2 BHK  Sothin
# 3            Plot  Area  Ready To Move        Thane  2 Bedroom      NaN
# 4  Super built-up  Area  Ready To Move  Navi Mumbai      2 BHK  Prncyrn
#
#    total_sqft  bath  balcony  price price_category
# 0        1920   4.0      2.0  121.0      High Cost
# 1        1500   4.0      3.0  192.0      High Cost
# 2         925   2.0      1.0   55.0     Affordable
# 3         500   1.0      0.0   55.0     Affordable
# 4        1174   2.0      1.0   74.0     Affordable

# %% [markdown]
# ### <font color="purple">**Question5**</font>
#
# - Get all the rows that has prices greater than **mean/average** price of all houses

# %%
#write condition here
df.price.mean()
# Out:
# np.float64(82.07080000000002)
