# %% [markdown]
# ## <font color="blue">About the data</font>
# - The file **grocery_data.csv** lists the monthly prices of Apple, Banana, Grapes, Mango, and Water Melons from January to October 2022.
# - Your task is to fill in the missing values according to the given instructions.

# %%
import pandas as pd

# %% [markdown]
# ### <font color="purple">**Question1**</font>
# - Read the csv file 'fruits_data.csv' into the dataframe 'df'.
# - show the number of rows and columns in it.
# - list all the columns present in the dataframe.
# - show the dataframe

# %%
#read the csv file
df=pd.read_csv("grocery_data.csv")

#show the number of rows and columns
df.shape

#list all the columns


#show the dataframe
# Out:
# (10, 6)

# %%
df.columns
# Out:
# Index(['date', 'milk(1L)', 'bread(1 loaf)', 'tomato(1kg)', 'rice(1kg)',
#        'cooking oil(1L)'],
#       dtype='object')

# %%
df
# Out:
#          date  milk(1L)  bread(1 loaf)  tomato(1kg)  rice(1kg)  \
# 0  02-01-2022      58.0           35.0         72.0       48.0
# 1  02-02-2022      60.0            NaN         74.0        NaN
# 2  02-03-2022       NaN           36.0         73.0       50.0
# 3  02-04-2022      62.0           37.0          NaN       49.0
# 4  02-05-2022      61.0           35.0         75.0       51.0
# 5  02-06-2022      59.0           34.0         76.0        NaN
# 6  02-07-2022       NaN           36.0         74.0       52.0
# 7  02-08-2022      63.0            NaN         73.0       53.0
# 8  02-09-2022      64.0           38.0          NaN       51.0
# 9  02-10-2022      62.0           37.0         77.0       50.0
#
#    cooking oil(1L)
# 0            155.0
# 1            157.0
# 2              NaN
# 3            160.0
# 4            158.0
# 5            159.0
# 6              NaN
# 7            161.0
# 8            162.0
# 9            160.0

# %% [markdown]
# ### <font color="purple">**Question2**</font>
# - Fill all the null values in the dataframe with '-1' and store the result to variable 'new_df'.

# %%
#fill null values with -1 and store it to 'new_df'
new_df=df.fillna(-1)

#show the dataframe 'new_df'
new_df
# Out:
#          date  milk(1L)  bread(1 loaf)  tomato(1kg)  rice(1kg)  \
# 0  02-01-2022      58.0           35.0         72.0       48.0
# 1  02-02-2022      60.0           -1.0         74.0       -1.0
# 2  02-03-2022      -1.0           36.0         73.0       50.0
# 3  02-04-2022      62.0           37.0         -1.0       49.0
# 4  02-05-2022      61.0           35.0         75.0       51.0
# 5  02-06-2022      59.0           34.0         76.0       -1.0
# 6  02-07-2022      -1.0           36.0         74.0       52.0
# 7  02-08-2022      63.0           -1.0         73.0       53.0
# 8  02-09-2022      64.0           38.0         -1.0       51.0
# 9  02-10-2022      62.0           37.0         77.0       50.0
#
#    cooking oil(1L)
# 0            155.0
# 1            157.0
# 2             -1.0
# 3            160.0
# 4            158.0
# 5            159.0
# 6             -1.0
# 7            161.0
# 8            162.0
# 9            160.0

# %% [markdown]
# ### <font color="purple">**Question3**</font>
# Fill the null values in respective columns like below:
#
#     - milk(1L): Mean value of that column
#     - bread(1 loaf) Mean value of that column
#     - tomato(1kg): Median value of that column
#     - rice(1kg): Median value of that column
#     - Water Melons(1): Fill null values with "Not Available".
#
# Finally store the output to 'new_df' variable

# %%
#write the code to fill null values as per above condition
#store the result to 'new_df' variable
new_df=df.fillna({'milk(1L)':df['milk(1L)'].mean(),
                  'bread(1 loaf)':df['bread(1 loaf)'].mean(),
                  'tomato(1kg)':df['tomato(1kg)'].median(),
                  'rice(1kg)':df['rice(1kg)'].median(),
                  'Water Melons(1)':"Not Available"})

#show the dataframe 'new_df'
new_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'apple(1kg)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 #write the code to fill null values as per above condition
#       2 #store the result to 'new_df' variable
# ----> 3 new_df=df.fillna({'apple(1kg)':df['apple(1kg)'].mean(),
#       4                   'banana(1 dozen)':df['banana(1 dozen)'].mean(),
#       5                   'grapes(1kg)':df['grapes(1kg)'].median(),
#       6                   'mango(1kg)':df['mango(1kg)'].median(),
#       7                   'Water Melons(1)':"Not Available"})
#       9 #show the dataframe 'new_df'
#      10 new_df
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'apple(1kg)'

# %% [markdown]
# ### <font color="purple">**Question4**</font>
#
# - Fill the null values with the non-null value before it (Forward fill method)
# - Store the result in 'new_df'.

# %%
#fill null values using 'ffill'
new_df=df.ffill()

#show the dataframe 'new_df'
new_df

# %% [markdown]
# ### <font color="purple">**Question5**</font>
# - Drop the rows if it does not contain atleast 4 non-null values (use the concept of thresholding).
# - store the result in 'new_df'

# %%
#write the code here
new_df=df.dropna(thresh=4)

#show the dataframe 'new_df'
new_df

# %% [markdown]
# ### <font color="purple">**Question6**</font>
#
#
# - Finally, remove the row if it contain null value and store the result in 'new_df'
# - save that dataframe to csv:'final_data.csv' and make sure to set index to False

# %%
#write the code here
new_df=df.dropna()


#show the dataframe 'new_df'
new_df

# %%
#save the dataframe to 'final_data.csv'
new_df.to_csv('final_data.csv')
