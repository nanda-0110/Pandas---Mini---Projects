# %%
import pandas as pd

# %%
df=pd.read_csv("Movie_Analysis.csv")

# %%
df
# Out:
#                                                 title   industry  \
# 0                                   Avengers: Endgame  Hollywood
# 1                             The Dark Knight Returns  Hollywood
# 2                             Thor: Love and Thunder   Hollywood
# 3                            The Kashmir Files Legacy  Bollywood
# 4                                                 RRR  Bollywood
# 5                              Taare Zameen Par Redux  Bollywood
# 6                                 Interstellar Legacy  Hollywood
# 7                         Munna Bhai M.B.B.S. Returns  Bollywood
# 8                               Bajirao Mastani  Saga  Bollywood
# 9                                      Parasite Redux  Hollywood
# 10                                    Gladiator Redux  Hollywood
# 11                                 Jurassic Park Saga  Hollywood
# 12                                 The Godfather Saga  Hollywood
# ...

# %%
Total_Number_Of_Movies=df.title.size
print("Total Number Of Movies In The List:",Total_Number_Of_Movies)
# Out:
# Total Number Of Movies In The List: 37

# %%
Total_Number_Of_Studios=df.studio.unique().size
print("Total Number Of Studio:",Total_Number_Of_Studios)
# Out:
# Total Number Of Studio: 22

# %%
Total_Number_Of_Languages=df.language.unique().size
print("Total Number Of Languages:",Total_Number_Of_Languages)
# Out:
# Total Number Of Languages: 5

# %%
Highest_IMDB_Rating=df[df.imdb_rating==df.imdb_rating.max()]
Highest_IMDB_Rating
# Out:
#                        title   industry  release_year  imdb_rating  \
# 18  The Shawshank Redemption  Hollywood          1994          9.2
#
#                        studio  budget  revenue      unit currency language
# 18  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
Lowest_IMDB_Rating=df[df.imdb_rating==df.imdb_rating.min()]
Lowest_IMDB_Rating
# Out:
#      title   industry  release_year  imdb_rating             studio  budget  \
# 17  Race 3  Bollywood          2018          1.7  Salman Khan Films     1.8
#
#     revenue      unit currency language
# 17      3.1  Billions      INR    Hindi

# %%
Highest_Revenue_USD=df[df.currency=="USD"]
Highest_Revenue_USD[Highest_Revenue_USD.revenue==Highest_Revenue_USD.revenue.max()]
# Out:
#      title   industry  release_year  imdb_rating            studio  budget  \
# 19  Avatar  Hollywood          2009          7.7  20th Century Fox   237.0
#
#     revenue      unit currency language
# 19   2847.0  Millions      USD  English

# %%
Lowest_Revenue_Movie=df[df.unit=="Thousands"]
Lowest_Revenue_Movie[Lowest_Revenue_Movie.revenue==Lowest_Revenue_Movie.revenue.min()]
# Out:
#                    title   industry  release_year  imdb_rating  \
# 16  Pather Panchali Saga  Bollywood          1955          8.1
#
#                        studio   budget   revenue       unit currency language
# 16  Government of West Bengal  70000.0  100000.0  Thousands      INR  Bengali

# %%
Highest_Budget_Movie=df[df.currency=="USD"]
Highest_Budget_Movie[Highest_Budget_Movie.budget==Highest_Budget_Movie.budget.max()]
# Out:
#                            title   industry  release_year  imdb_rating  \
# 0              Avengers: Endgame  Hollywood          2019          8.2
# 32  Avengers: Infinity War Redux  Hollywood          2018          8.3
#
#             studio  budget  revenue      unit currency language
# 0   Marvel Studios   400.0   2798.0  Millions      USD  English
# 32  Marvel Studios   400.0   2048.0  Millions      USD  English

# %%
Lowest_Budget_INR=df[df.currency=="INR"]
Lowest_Budget_INR[Lowest_Budget_INR.budget==Lowest_Budget_INR.budget.min()]
# Out:
#                title   industry  release_year  imdb_rating  \
# 27  K.G.F: Chapter 2  Bollywood          2022          8.3
# 36      Sanju Reborn  Bollywood          2018          NaN
#
#                 studio  budget  revenue      unit currency language
# 27       Hombale Films     1.0     12.5  Billions      INR  Kannada
# 36  Vinod Chopra Films     1.0      5.9  Billions      INR    Hindi

# %%
df["Profit"]=df.apply(lambda x:x["revenue"]-x["budget"],axis=1)
df
# Out:
#                                                 title   industry  \
# 0                                   Avengers: Endgame  Hollywood
# 1                             The Dark Knight Returns  Hollywood
# 2                             Thor: Love and Thunder   Hollywood
# 3                            The Kashmir Files Legacy  Bollywood
# 4                                                 RRR  Bollywood
# 5                              Taare Zameen Par Redux  Bollywood
# 6                                 Interstellar Legacy  Hollywood
# 7                         Munna Bhai M.B.B.S. Returns  Bollywood
# 8                               Bajirao Mastani  Saga  Bollywood
# 9                                      Parasite Redux  Hollywood
# 10                                    Gladiator Redux  Hollywood
# 11                                 Jurassic Park Saga  Hollywood
# 12                                 The Godfather Saga  Hollywood
# ...

# %%
Highest_Profitable_Movie=df[df.currency=="USD"]
Highest_Profitable_Movie[Highest_Profitable_Movie.Profit==Highest_Profitable_Movie.Profit.max()]
# Out:
#      title   industry  release_year  imdb_rating            studio  budget  \
# 19  Avatar  Hollywood          2009          7.7  20th Century Fox   237.0
#
#     revenue      unit currency language  Profit
# 19   2847.0  Millions      USD  English  2610.0

# %%
Lowest_Profitable_Movie=df[df.currency=="INR"]
Lowest_Profitable_Movie[Lowest_Profitable_Movie.Profit==Lowest_Profitable_Movie.Profit.min()]
# Out:
#      title   industry  release_year  imdb_rating             studio  budget  \
# 17  Race 3  Bollywood          2018          1.7  Salman Khan Films     1.8
#
#     revenue      unit currency language  Profit
# 17      3.1  Billions      INR    Hindi     1.3

# %%
df["Profit_Percentage"]=df.apply(lambda x:(x["revenue"]-x["budget"])/x["budget"]*100,axis=1)
df
# Out:
#                                                 title   industry  \
# 0                                   Avengers: Endgame  Hollywood
# 1                             The Dark Knight Returns  Hollywood
# 2                             Thor: Love and Thunder   Hollywood
# 3                            The Kashmir Files Legacy  Bollywood
# 4                                                 RRR  Bollywood
# 5                              Taare Zameen Par Redux  Bollywood
# 6                                 Interstellar Legacy  Hollywood
# 7                         Munna Bhai M.B.B.S. Returns  Bollywood
# 8                               Bajirao Mastani  Saga  Bollywood
# 9                                      Parasite Redux  Hollywood
# 10                                    Gladiator Redux  Hollywood
# 11                                 Jurassic Park Saga  Hollywood
# 12                                 The Godfather Saga  Hollywood
# ...

# %%
Most_Profit_Percentage=df[df.Profit_Percentage==df.Profit_Percentage.max()]
Most_Profit_Percentage
# Out:
#                  title   industry  release_year  imdb_rating  \
# 12  The Godfather Saga  Hollywood          1972          9.1
#
#                 studio  budget  revenue      unit currency language  Profit  \
# 12  Paramount Pictures     7.2    291.0  Millions      USD  English   283.8
#
#     Profit_Percentage
# 12        3941.666667

# %%
Least_Profit_Percentage=df[df.Profit_Percentage==df.Profit_Percentage.min()]
Least_Profit_Percentage
# Out:
#                     title   industry  release_year  imdb_rating  \
# 30  It's a Wonderful Life  Hollywood          1946          8.6
#
#            studio  budget  revenue      unit currency language  Profit  \
# 30  Liberty Films    3.18      3.3  Millions      USD  English    0.12
#
#     Profit_Percentage
# 30           3.773585

# %%
idx=df[df.studio=="Marvel Studios"].imdb_rating.idxmax()
df.loc[idx]
# Out:
# title                Avengers: Infinity War Redux
# industry                                Hollywood
# release_year                                 2018
# imdb_rating                                   8.3
# studio                             Marvel Studios
# budget                                      400.0
# revenue                                    2048.0
# unit                                     Millions
# currency                                      USD
# language                                  English
# Profit                                     1648.0
# Profit_Percentage                           412.0
# Name: 32, dtype: object

# %%
avg_HollyWood_IMDB=df[df.industry=="Hollywood"].imdb_rating.mean()
print("Average Hollywood Rating:",avg_HollyWood_IMDB)
# Out:
# Average Hollywood Rating: 8.135000000000002

# %%
avg_BollyWood_IMDB=df[df.industry=="Bollywood"].imdb_rating.mean()
print("Average BollyWood Rating:",avg_BollyWood_IMDB)
# Out:
# Average BollyWood Rating: 7.60625

# %%
avg_HollyWood_Revenue=df[df.industry=="Hollywood"].revenue.mean()
print("Average Hollywood revenue:",avg_HollyWood_Revenue)
# Out:
# Average Hollywood revenue: 928.8950000000001

# %%
avg_BollyWood_Revenue=df[df.industry=="Bollywood"].revenue.mean()
print("Average Bollywood revenue:",avg_BollyWood_Revenue)
# Out:
# Average Bollywood revenue: 7868.005882352942

# %%
df["age"]=df.apply(lambda x:2026-x["release_year"],axis=1)
df
# Out:
#                                                 title   industry  \
# 0                                   Avengers: Endgame  Hollywood
# 1                             The Dark Knight Returns  Hollywood
# 2                             Thor: Love and Thunder   Hollywood
# 3                            The Kashmir Files Legacy  Bollywood
# 4                                                 RRR  Bollywood
# 5                              Taare Zameen Par Redux  Bollywood
# 6                                 Interstellar Legacy  Hollywood
# 7                         Munna Bhai M.B.B.S. Returns  Bollywood
# 8                               Bajirao Mastani  Saga  Bollywood
# 9                                      Parasite Redux  Hollywood
# 10                                    Gladiator Redux  Hollywood
# 11                                 Jurassic Park Saga  Hollywood
# 12                                 The Godfather Saga  Hollywood
# ...

# %%
age_idx=df.age.idxmax()
df.iloc[age_idx]
# Out:
# title                It's a Wonderful Life
# industry                         Hollywood
# release_year                          1946
# imdb_rating                            8.6
# studio                       Liberty Films
# budget                                3.18
# revenue                                3.3
# unit                              Millions
# currency                               USD
# language                           English
# Profit                                0.12
# Profit_Percentage                 3.773585
# age                                     80
# Name: 30, dtype: object

# %%
age_new_idx=df.age.min()
df.iloc[age_new_idx]
# Out:
# title                              RRR
# industry                     Bollywood
# release_year                      2022
# imdb_rating                        7.9
# studio               DVV Entertainment
# budget                             5.5
# revenue                           12.0
# unit                          Billions
# currency                           INR
# language                        Telugu
# Profit                             6.5
# Profit_Percentage           118.181818
# age                                  4
# Name: 4, dtype: object
